# %%
from google.colab import files
from google.cloud import storage

# %%
from google.colab import auth
auth.authenticate_user()
# Out:
# Updated property [core/project].

# %%
# copy some images to see what they look like
# !gsutil cp -r gs://public-datasets-lila/orinoquia-camera-traps/public/A01/01090079.JPG .
# Out:
# Copying gs://public-datasets-lila/orinoquia-camera-traps/public/A01/01090079.JPG...
# / [1 files][754.5 KiB/754.5 KiB]
# Operation completed over 1 objects/754.5 KiB.

# %%
# !mkdir /all_images

# %%
# !gsutil cp -r gs://public-datasets-lila/orinoquia-camera-traps ../all_images/
# Out:
# Copying gs://public-datasets-lila/orinoquia-camera-traps/orinoquia_camera_traps_images.zip...
# ==> NOTE: You are downloading one or more large file(s), which would
# run significantly faster if you enabled sliced object downloads. This
# feature is enabled by default but requires that compiled crcmod be
# installed (see "gsutil help crcmod").
#
# Caught CTRL-C (signal 2) - exiting
# ^C

# %%
image_path = "./all_images/A1/04270694.JPG"

from matplotlib.pyplot import imread, imshow

# Load the image
img = imread(image_path)

# Display the image
imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-91a3d24b7f8d> in <cell line: 6>()
#       4
#       5 # Load the image
# ----> 6 img = imread(image_path)
#       7
#       8 # Display the image
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2193 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2194 def imread(fname, format=None):
# -> 2195     return matplotlib.image.imread(fname, format)
#    2196
#    2197
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imread(fname, format)
#    1561             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562             )
# -> 1563     with img_open(fname) as image:
#    1564         return (_pil_png_to_float_array(image)
#    1565                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ...
